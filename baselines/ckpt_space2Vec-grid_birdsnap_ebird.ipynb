# %%
import torch

# %%
#model_path = f"TorchSpatial/pre_trained_models/space2vec_grid/model_birdsnap_ebird_{loc_encoder_name}_trained{trained_epochs}_debiased{debiased_epochs}.pth.tar"
model_path = "TorchSpatial/pre_trained_models/space2vec_grid/model_birdsnap_ebird_meta_Space2Vec-grid_inception_v3_0.0100_128_0.1000000_360.000_1_512_leakyrelu.pth.tar"
ckpt = torch.load(model_path, map_location='cpu')

# %%
ckpt.keys()
# Out:
# dict_keys(['epoch', 'state_dict', 'optimizer', 'params'])

# %%
ckpt["params"]
# Out:
# {'unsuper_dataset': 'birdsnap',
#  'unsuper_meta_type': 'birdsnap',
#  'dataset': 'birdsnap',
#  'meta_type': 'ebird_meta',
#  'eval_split': 'test',
#  'load_val_op': True,
#  'cnn_model': 'inception_v3',
#  'load_cnn_predictions': False,
#  'load_cnn_features': False,
#  'load_cnn_features_train': False,
#  'load_img': False,
#  'inat2018_resolution': 'standard',
#  'cnn_pred_type': 'full',
#  'device': 'cuda:3',
#  'model_dir': '../models/space2vec_grid/',
#  'num_epochs': 30,
#  'num_epochs_unsuper': 30,
#  'spa_enc_type': 'Space2Vec-grid',
#  'frequency_num': 128,
#  'max_radius': 360.0,
#  'min_radius': 0.1,
#  'num_hidden_layer': 1,
#  'hidden_dim': 512,
#  'num_rbf_anchor_pts': 200,
#  'rbf_kernel_size': 1.0,
#  'loc_encode': 'encode_cos_sin',
#  'num_filts': 256,
#  'freq_init': 'geometric',
#  'spa_f_act': 'leakyrelu',
#  'map_range': [-180, 180, -90, 90],
#  'use_layn': True,
#  'skip_connection': True,
#  'spa_enc_use_postmat': True,
#  'use_date_feats': False,
# ...
